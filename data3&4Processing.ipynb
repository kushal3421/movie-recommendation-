# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # package for reading html sites
# pip install lxml

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1=pd.read_html(link,header=0)[2]
df2=pd.read_html(link,header=0)[3]
df3=pd.read_html(link,header=0)[4]
df4=pd.read_html(link,header=0)[5]

# %%
df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\3617246550.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.head()
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
# 1  J A N U A R Y          5         The Strange Ones
# 2  J A N U A R Y          5                 Stratton
# 3  J A N U A R Y         10            Sweet Country
# 4  J A N U A R Y         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# ...

# %% [markdown]
# #install tmdb api for findig genres of movies

# %%
pip install tmdbv3api
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tmdbv3api import TMDb
import json 
import requests
tmdb=TMDb()
tmdb.api_key='8adad600aa361bb1349465ffecb76997'

# %%
from tmdbv3api import Movie
tmdb_movie=Movie()
def get_genre(x):
    genres=[]
    result=tmdb_movie.search(x)
    movie_id=result[0].id
    response=requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json=response.json()
    if data_json['genres']:
        genre_str=" "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['Genre'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 269  D E C E M B E R         25             Holmes & Watson
# 270  D E C E M B E R         25                        Vice
# 271  D E C E M B E R         25         On the Basis of Sex
# 272  D E C E M B E R         25                   Destroyer
# 273  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# ...

# %%
df_3=df[['Title','Cast and crew','Genre']]

# %%
def director(x):
    if "(director)" in x:
        return x.split("(director)")[0]
    elif "(directors)" in x:
        return x.split("(directors)")[0]
    else:
        return x.split("(director/screenplay)")[0]

# %%
df_3['director_name']=df_3['Cast and crew'].map(lambda x: director(x))

# %%
def actor_1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_3['actor_1_name']=df_3['Cast and crew'].map(lambda x: actor_1(x))
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\1891651184.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['actor_1_name']=df_3['Cast and crew'].map(lambda x: actor_1(x))

# %%
def actor_2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2 :
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_3['actor_2_name']=df_3['Cast and crew'].map(lambda x: actor_2(x))
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\404149027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['actor_2_name']=df_3['Cast and crew'].map(lambda x: actor_2(x))

# %%
def actor_3(x):
    if len((x.split("screenplay); ")[-1]).split(", "))<3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_3['actor_3_name']=df_3['Cast and crew'].map(lambda x: actor_3(x))
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\2318798303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['actor_3_name']=df_3['Cast and crew'].map(lambda x: actor_3(x))

# %%
df_3
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 269             Holmes & Watson
# 270                        Vice
# 271         On the Basis of Sex
# 272                   Destroyer
# 273  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 269  Etan Cohen (director/screenplay); Will Ferrell...
# 270  Adam McKay (director/screenplay); Christian Ba...
# 271  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_3=df_3.rename(columns={'Title':'movie_title'})

# %%
df_3=df_3.rename(columns={'Genre':'genres'})

# %%
data_3=df_3.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
data_3
# Out:
#            director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel         Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein     Alex Pettyfer  James Freedson-Jackson
# 2            Simon West    Dominic Cooper          Austin Stowell
# 3      Warwick Thornton       Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra       Liam Neeson            Vera Farmiga
# ..                   ...              ...                     ...
# 269          Etan Cohen      Will Ferrell          John C. Reilly
# 270          Adam McKay    Christian Bale               Amy Adams
# 271          Mimi Leder    Felicity Jones            Armie Hammer
# 272        Karyn Kusama     Nicole Kidman          Sebastian Stan
# 273         David Slade   Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
data_3['actor_2_name']=data_3['actor_2_name'].replace(np.nan,'unknown')
data_3['actor_3_name']=data_3['actor_3_name'].replace(np.nan,'unknown')

# %%
data_3['movie_title']=data_3['movie_title'].str.lower()

# %%
data_3['comb']=data_3['actor_1_name'] + ' ' + data_3['actor_2_name'] + ' ' + data_3['actor_3_name'] + ' ' + data_3['director_name'] + " " + data_3['genres']

# %%
data_3
# Out:
#            director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel         Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein     Alex Pettyfer  James Freedson-Jackson
# 2            Simon West    Dominic Cooper          Austin Stowell
# 3      Warwick Thornton       Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra       Liam Neeson            Vera Farmiga
# ..                   ...              ...                     ...
# 269          Etan Cohen      Will Ferrell          John C. Reilly
# 270          Adam McKay    Christian Bale               Amy Adams
# 271          Mimi Leder    Felicity Jones            Armie Hammer
# 272        Karyn Kusama     Nicole Kidman          Sebastian Stan
# 273         David Slade   Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %% [markdown]
# Extracting data for 2019 movies

# %%
link="https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1=pd.read_html(link,header=0)[2]
df2=pd.read_html(link,header=0)[3]
df3=pd.read_html(link,header=0)[4]
df4=pd.read_html(link,header=0)[5]

# %%
df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\3617246550.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 240  D E C E M B E R         25  Spies in Disguise
# 241  D E C E M B E R         25       Little Women
# 242  D E C E M B E R         25               1917
# 243  D E C E M B E R         25         Just Mercy
# 244  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_4 = df[['Title','Cast and crew','genres']]

# %%
df_4
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 240  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 241       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 242               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 243         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 244           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# ...

# %%
def director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_4['director_name'] = df_4['Cast and crew'].map(lambda x: director(str(x)))
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\3884073486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4['director_name'] = df_4['Cast and crew'].map(lambda x: director(str(x)))

# %%
def actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_4['actor_1_name'] = df_4['Cast and crew'].map(lambda x: actor1(x))
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\3590729423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4['actor_1_name'] = df_4['Cast and crew'].map(lambda x: actor1(x))

# %%
def actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_4['actor_2_name'] = df_4['Cast and crew'].map(lambda x: actor2(x))
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\2224003217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4['actor_2_name'] = df_4['Cast and crew'].map(lambda x: actor2(x))

# %%
def actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_4['actor_3_name'] = df_4['Cast and crew'].map(lambda x: actor3(x))

# %%
df_4 = df_4.rename(columns={'Title':'movie_title'})

# %%
data_4 = df_4.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
data_4['actor_2_name'] = data_4['actor_2_name'].replace(np.nan, 'unknown')
data_4['actor_3_name'] = data_4['actor_3_name'].replace(np.nan, 'unknown')

# %%
data_4['movie_title']=data_4['movie_title'].str.lower()

# %%
data_4['comb']=data_4['actor_1_name'] + ' ' + data_4['actor_2_name'] + ' ' + data_4['actor_3_name'] + ' ' + data_4['director_name'] + " " + data_4['genres']

# %%
data_4.head()
# Out:
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
#
#        actor_3_name                       genres       movie_title  \
# 0  Deborah Ann Woll      Horror Thriller Mystery       escape room
# 1      Sean O'Bryan  Thriller Drama Action Crime        rust creek
# 2     Oliver Dennis                     Thriller  american hangman
# 3   Alexandra Shipp       Drama Adventure Family  a dog's way home
# 4     Nicole Kidman                 Comedy Drama        the upside
#
#                                                 comb
# 0  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# ...

# %%
new_df=data_3.append(data_4,ignore_index=True)
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\3273994702.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df=data_3.append(data_4,ignore_index=True)

# %%
data_2=pd.read_csv('data2.csv')

# %%
data_2
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
data_upto4=data_2.append(new_df,ignore_index=True)
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\410648609.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_upto4=data_2.append(new_df,ignore_index=True)

# %%
data_upto4
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5878  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5879            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5880              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5881   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5882         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# ...

# %%
data_upto4.to_csv('data3&4.csv',index=False)

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1=pd.read_html(link,header=0)[2]
df2=pd.read_html(link,header=0)[3]
df3=pd.read_html(link,header=0)[4]
df4=pd.read_html(link,header=0)[5]

# %%
df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\MAHAK\AppData\Local\Temp\ipykernel_1308\3617246550.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.head()
# Out:
#          Opening  Opening.1              Title  \
# 0  J A N U A R Y          3         The Grudge
# 1  J A N U A R Y         10         Underwater
# 2  J A N U A R Y         10        Like a Boss
# 3  J A N U A R Y         10      Three Christs
# 4  J A N U A R Y         10  Inherit the Viper
#
#                                   Production company  \
# 0  Screen Gems / Stage 6 Films / Ghost House Pict...
# 1  20th Century Fox / TSG Entertainment / Chernin...
# 2                                 Paramount Pictures
# 3                                          IFC Films
# 4     Barry Films / Tycor International Film Company
#
#                                        Cast and crew  \
# 0  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1  William Eubank (director); Brian Duffield, Ada...
# 2  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Anthony Jerjen (director); Andrew Crabtree (sc...
#
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [78], line 1
# ----> 1 df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4537     dtype: object
#    4538     """
# -> 4539     new_values = self._map_values(arg, na_action=na_action)
#    4540     return self._constructor(new_values, index=self.index).__finalize__(
#    4541         self, method="map"
#    4542     )
#
# ...

# %%
df_5 = df[['Title','Cast and crew','genres']]
